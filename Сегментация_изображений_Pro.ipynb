# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexandr-M-85/Neural-University/blob/main/%D0%A1%D0%B5%D0%B3%D0%BC%D0%B5%D0%BD%D1%82%D0%B0%D1%86%D0%B8%D1%8F_%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B9_Pro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. На основе учебного ноутбука проведите финальную подготовку данных. Измените количество сегментирующих классов с `16` на `7`:
#   - 0_класс - FLOOR
#   - 1_класс - CEILING
#   - 2_класс - WALL
#   - 3_класс - APERTURE, DOOR, WINDOW
#   - 4_класс - COLUMN, RAILINGS, LADDER
#   - 5_класс - INVENTORY
#   - 6_класс - LAMP, WIRE, BEAM, EXTERNAL, BATTERY,
# PEOPLE
#
# 2. Изучите внимательно особенности `U-net`, определите в чем принципиальное отличие  `U-net `  и   `simpleUnet` из учебного ноутбука.
#
# 3. Доработайте `simpleUnet` с учетом особенностей `U-net `. Обучите модель на 100 эпохах и визуализируйте результат.
#
# **Важно!**
#
# Многие эксперименты могут приводить к переполнению ОЗУ в вашем ноутбуке и сброса кода обучения.
#
# ![image.png](data:image/png;base64,...)
#
# Для предотвращения переполнения ОЗУ может помочь библиотека `gc`. Вставьте строчку `gc.collect()` в цикл ваших экспериментов для сбора и удаления временных данных (кеш).

# %% [markdown]
# Перед выполнением задания, пожалуйста, запустите ячейку `Подготовка` ниже:

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Импорт библиотек

# %%
 # Импортируем модели keras: Model
from tensorflow.keras.models import Model

 # Импортируем стандартные слои keras
from tensorflow.keras.layers import Input, Conv2DTranspose, concatenate, Activation
from tensorflow.keras.layers import MaxPooling2D, Conv2D, BatchNormalization, UpSampling2D

# Импортируем модуль backend keras'а
from tensorflow.keras import backend as K 

# Импортируем оптимизатор Adam
from tensorflow.keras.optimizers import Adam 

# Импортируем модуль pyplot библиотеки matplotlib для построения графиков
import matplotlib.pyplot as plt 

# Импортируем модуль image для работы с изображениями
from tensorflow.keras.preprocessing import image 

# Импортируем библиотеку numpy
import numpy as np 

# Импортируем методделения выборки
from sklearn.model_selection import train_test_split

# загрузка файлов по HTML ссылке
import gdown

# Для работы с файлами 
import os 

# Для генерации случайных чисел 
import random

import time

# импортируем модель Image для работы с изображениями
from PIL import Image 

# очистка ОЗУ
import gc

# %% [markdown]
# ### Загрузка датасета
#
# грузим и распаковываем архив картинок

# %%
# Загрузка датасета из облака
#gdown.download('https://storage.googleapis.com/datasets_ai/Base/15_segmentation/construction_1024x768.zip', None, quiet=True)
#gdown.download('https://storage.googleapis.com/datasets_ai/Base/15_segmentation/construction_512x384.zip', None, quiet=True)
gdown.download('https://storage.googleapis.com/datasets_ai/Base/15_segmentation/construction_256x192.zip', None, quiet=True)

# !unzip -q 'construction_256x192.zip' # распоковываем архив

# %% [markdown]
# ### Предварительная подготовка данных

# %%
# Глобальные параметры

IMG_WIDTH = 192               # Ширина картинки 
IMG_HEIGHT = 256             # Высота картинки 
NUM_CLASSES = 16              # Задаем количество классов на изображении
TRAIN_DIRECTORY = 'train'     # Название папки с файлами обучающей выборки
VAL_DIRECTORY = 'val'         # Название папки с файлами проверочной выборки

# %% [markdown]
# Загрузим оригинальные изображения (код из лекции):

# %%
train_images = [] # Создаем пустой список для хранений оригинальных изображений обучающей выборки
val_images = [] # Создаем пустой список для хранений оригинальных изображений проверочной выборки

cur_time = time.time()  # Засекаем текущее время

# Проходим по всем файлам в каталоге по указанному пути  
for filename in sorted(os.listdir(TRAIN_DIRECTORY+'/original')):   
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size
    train_images.append(image.load_img(os.path.join(TRAIN_DIRECTORY+'/original',filename),
                                       target_size=(IMG_WIDTH, IMG_HEIGHT)))               
    
# Отображаем время загрузки картинок обучающей выборки    
print ('Обучающая выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='') 

# Отображаем количество элементов в обучающей выборке
print ('Количество изображений: ', len(train_images)) 

cur_time = time.time() # Засекаем текущее время

# Проходим по всем файлам в каталоге по указанному пути
for filename in sorted(os.listdir(VAL_DIRECTORY+'/original')):
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size   
    val_images.append(image.load_img(os.path.join(VAL_DIRECTORY+'/original',filename), 
                                     target_size=(IMG_WIDTH, IMG_HEIGHT)))  

# Отображаем время загрузки картинок проверочной выборки
print ('Проверочная выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='') 

# Отображаем количество элементов в проверочной выборке
print ('Количество изображений: ', len(val_images))
# Out:
# Обучающая выборка загружена. Время загрузки: 0.28c
# Количество изображений:  1900
# Проверочная выборка загружена. Время загрузки: 0.02c
# Количество изображений:  100

# %% [markdown]
# Загрузим сегментированные изображения (код из лекции):

# %%
train_segments = [] # Создаем пустой список для хранений оригинальных изображений обучающей выборки
val_segments = [] # Создаем пустой список для хранений оригинальных изображений проверочной выборки

cur_time = time.time() # Засекаем текущее время

for filename in sorted(os.listdir(TRAIN_DIRECTORY+'/segment')): # Проходим по всем файлам в каталоге по указанному пути     
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size  
    train_segments.append(image.load_img(os.path.join(TRAIN_DIRECTORY+'/segment',filename),
                                       target_size=(IMG_WIDTH, IMG_HEIGHT)))                                                     
    
# Отображаем время загрузки картинок обучающей выборки
print ('Обучающая выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='') 

# Отображаем количество элементов в обучающем наборе сегментированных изображений
print ('Количество изображений: ', len(train_segments)) 

cur_time = time.time() # Засекаем текущее время

for filename in sorted(os.listdir(VAL_DIRECTORY+'/segment')): # Проходим по всем файлам в каталоге по указанному пути
    # Читаем очередную картинку и добавляем ее в список изображений с указанным target_size                                                      
    val_segments.append(image.load_img(os.path.join(VAL_DIRECTORY+'/segment',filename), 
                                     target_size=(IMG_WIDTH, IMG_HEIGHT)))  

# Отображаем время загрузки картинок проверочной выборки
print ('Проверочная выборка загружена. Время загрузки: ', round(time.time() - cur_time, 2), 'c', sep='')

# Отображаем количество элементов в проверочном наборе сегментированных изображений
print ('Количество изображений: ', len(val_segments))
# Out:
# Обучающая выборка загружена. Время загрузки: 0.24c
# Количество изображений:  1900
# Проверочная выборка загружена. Время загрузки: 0.01c
# Количество изображений:  100

# %% [markdown]
# ## Решение

# %%
# просмотр оригинальных изображений и соответствующих им сегментированных изображений

# создаем полотно
plt.figure(figsize=(25, 8))
for i in range(5):
    # выбираем рандомно номер изображения
    img = random.randint(0, len(train_images))

    plt.subplot(2, 5, i+1)
    plt.title('Оригинальное изображение')
    plt.imshow(train_images[img])
    plt.axis('off')

    plt.subplot(2, 5, i+6)
    plt.title('Сегментированное изображение')
    plt.imshow(train_segments[img])
    plt.axis('off')

plt.show()

# %%
# зададим цвета пикселей каждого из 16 классов
FLOOR = (100, 100, 100)         # Пол (серый)
CEILING = (0, 0, 100)           # Потолок (синий)
WALL = (0, 100, 0)              # Стена (зеленый)
APERTURE = (0, 100, 100)        # Проем (темно-бирюзовый)
DOOR = (100, 0, 100)            # Дверь (бордовый)
WINDOW = (100, 100, 0)          # Окно (золотой)
COLUMN = (100, 0, 0)            # Колонна (красный)
RAILINGS = (0, 200, 0)          # Перила (светло-зеленый)
LADDER = (0, 0, 200)            # Лестница (светло-синий)
INVENTORY = (200, 0, 200)       # Инвентарь (розовый)
EXTERNAL = (200, 200, 200)      # Внешний мир (светло-серый)
BATTERY = (200, 0, 0)           # Батареи (светло-красный)
PEOPLE = (0, 200, 200)          # Люди (бирюзовый)
LAMP = (200, 200, 0)            # Лампа (желтый)
WIRE = (0, 100, 200)            # Провод (голубой)
BEAM = (100, 0, 200)            # Балка (фиолетовый)

# сохраним в множество
CLASS_LABELS = (FLOOR, CEILING, WALL, APERTURE, DOOR, WINDOW, COLUMN, RAILINGS, LADDER, INVENTORY, EXTERNAL, BATTERY, PEOPLE, LAMP, WIRE, BEAM)

# %%
# Функция преобразования цветного сегментированного изображения в метки классов
def rgb_to_labels(image_list):
    """
    Функция преобразует трехцветный канал изображения в метку класса
    На вход подается список изображений
    Возвращается список тензоров размера ширина на высота изображения
    """

    result = []
  
    # Для всех картинок в списке:
    for d in image_list:
        sample = np.array(d)
        # Создание пустой 1-канальной картинки
        y = np.zeros((IMG_WIDTH, IMG_HEIGHT, 1), dtype='uint8')
        
        # По всем классам:
        for i, cl in enumerate(CLASS_LABELS): 
            # Нахождение 3-х канальных пикселей классов и занесение метки класса
            y[np.where(np.all(sample == CLASS_LABELS[i], axis=-1))] = i
        result.append(y)
  
    return np.array(result)


# Функция преобразования тензора меток класса в цветное сегментированное изображение
def labels_to_rgb(image_list):
    """
    Функция преобразует метку класса в цветное сегментированное изображение
    На вход подается список тензоров с метками классов
    Возвращается цветное сегментированное изображение 
    """

    result = []

    # Для всех картинок в списке:
    for y in image_list:
        # Создание пустой цветной картинки
        temp = np.zeros((IMG_WIDTH, IMG_HEIGHT, 3), dtype='uint8')
        
        # По всем классам:
        for i, cl in enumerate(CLASS_LABELS):
            # Нахождение пикселей класса и заполнение цветом из CLASS_LABELS[i]
            temp[np.where(np.all(y==i, axis=-1))] = CLASS_LABELS[i]

        result.append(temp)
  
    return np.array(result)

# %%
# сформируем обучающую выборку

# создадим пустой список под выборку
x_train = []

# для всех изображений выборки
for img in train_images:
    # переводим в изображение в 3-хмерный массив 
    x = image.img_to_array(img)
    # Добавление элемента в выборку
    x_train.append(x)

# Перевод всей выборки в numpy
x_train = np.array(x_train)


# аналогично сформируем проверочную выборку
x_val = []
for img in val_images:
    x = image.img_to_array(img)
    x_val.append(x)

x_val = np.array(x_val)


# Преобразование сегментов в метки классов
y_train = rgb_to_labels(train_segments)
y_val = rgb_to_labels(val_segments)

# посмотрим размерности
print(y_train.shape)
print(y_val.shape)
print(x_val.shape)
print(x_train.shape)
# Out:
# (1900, 192, 256, 1)
# (100, 192, 256, 1)
# (100, 192, 256, 3)
# (1900, 192, 256, 3)

# %%
# уменьшим количество сегментирующих классов до 7
y_train7 = y_train.copy()
y_train7[(y_train7 > 2) & (y_train7 < 6)] = 3
y_train7[(y_train7 > 5) & (y_train7 < 9)] = 4
y_train7[y_train7 == 9] = 5
y_train7[y_train7 > 9] = 6

y_val7 = y_val.copy()
y_val7[(y_val7 > 2) & (y_val7 < 6)] = 3
y_val7[(y_val7 > 5) & (y_val7 < 9)] = 4
y_val7[y_val7 == 9] = 5
y_val7[y_val7 > 9] = 6

# %%
# создаем модель U-net   
img_input = Input((192, 256, 3))

''' Block 1 '''

x = Conv2D(64, (3, 3), padding='same', name='block1_conv1')(img_input)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(64, (3, 3), padding='same', name='block1_conv2')(x)
x = BatchNormalization()(x)
block_1_out = Activation('relu')(x)

x = MaxPooling2D()(block_1_out)

''' Block 2 '''
x = Conv2D(128, (3, 3), padding='same', name='block2_conv1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(128, (3, 3), padding='same', name='block2_conv2')(x)
x = BatchNormalization()(x)
block_2_out = Activation('relu')(x)

x = MaxPooling2D()(block_2_out)

''' Block 3 '''
x = Conv2D(256, (3, 3), padding='same', name='block3_conv1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(256, (3, 3), padding='same', name='block3_conv2')(x)
x = BatchNormalization()(x)
block_3_out = Activation('relu')(x)

x = MaxPooling2D()(block_3_out)

''' Block 4 '''
x = Conv2D(512, (3, 3), padding='same', name='block4_conv1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(512, (3, 3), padding='same', name='block4_conv2')(x)
x = BatchNormalization()(x)
block_4_out = Activation('relu')(x)

x = MaxPooling2D()(block_4_out)

''' Block 5 '''
x = Conv2D(1024, (3, 3), padding='same', name='block5_conv1')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(1024, (3, 3), padding='same', name='block5_conv2')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

''' UP 1 '''
x = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = concatenate([block_4_out, x])
x = Conv2D(512, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(512, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

''' UP 2 '''
x = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = concatenate([block_3_out, x])
x = Conv2D(256, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(256, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

''' UP 3 '''
x = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = concatenate([block_2_out, x])
x = Conv2D(128, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(128, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

''' UP 4 '''
x = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = concatenate([block_1_out, x])
x = Conv2D(64, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(64, (3, 3), padding='same')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(7, (1, 1), activation='softmax', padding='same')(x)

model = Model(img_input, x)

# Компилируем модель
model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# обучаем модель
history = model.fit(x_train, y_train7, epochs=100, batch_size=32,
                    validation_data=(x_val, y_val7))
# Out:
# Epoch 1/100
# 60/60 [==============================] - 39s 619ms/step - loss: 1.4264 - sparse_categorical_accuracy: 0.5198 - val_loss: 805.1584 - val_sparse_categorical_accuracy: 0.0613
# Epoch 2/100
# 60/60 [==============================] - 37s 612ms/step - loss: 1.0206 - sparse_categorical_accuracy: 0.6535 - val_loss: 19.1399 - val_sparse_categorical_accuracy: 0.2098
# Epoch 3/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.9082 - sparse_categorical_accuracy: 0.6920 - val_loss: 3.8064 - val_sparse_categorical_accuracy: 0.3676
# Epoch 4/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.8282 - sparse_categorical_accuracy: 0.7207 - val_loss: 1.4518 - val_sparse_categorical_accuracy: 0.5905
# Epoch 5/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.7985 - sparse_categorical_accuracy: 0.7310 - val_loss: 1.7460 - val_sparse_categorical_accuracy: 0.5218
# Epoch 6/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.7615 - sparse_categorical_accuracy: 0.7408 - val_loss: 1.3985 - val_sparse_categorical_accuracy: 0.6026
# Epoch 7/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.7166 - sparse_categorical_accuracy: 0.7582 - val_loss: 1.3638 - val_sparse_categorical_accuracy: 0.5929
# Epoch 8/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.6923 - sparse_categorical_accuracy: 0.7662 - val_loss: 1.4691 - val_sparse_categorical_accuracy: 0.4331
# Epoch 9/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.6992 - sparse_categorical_accuracy: 0.7645 - val_loss: 1.1702 - val_sparse_categorical_accuracy: 0.6178
# Epoch 10/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.6467 - sparse_categorical_accuracy: 0.7832 - val_loss: 1.0983 - val_sparse_categorical_accuracy: 0.6461
# Epoch 11/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.6295 - sparse_categorical_accuracy: 0.7876 - val_loss: 1.5702 - val_sparse_categorical_accuracy: 0.5187
# Epoch 12/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.6053 - sparse_categorical_accuracy: 0.7965 - val_loss: 1.2491 - val_sparse_categorical_accuracy: 0.5957
# Epoch 13/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.5936 - sparse_categorical_accuracy: 0.7993 - val_loss: 0.9791 - val_sparse_categorical_accuracy: 0.6729
# Epoch 14/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.5806 - sparse_categorical_accuracy: 0.8034 - val_loss: 1.0465 - val_sparse_categorical_accuracy: 0.6608
# Epoch 15/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.5607 - sparse_categorical_accuracy: 0.8097 - val_loss: 1.1224 - val_sparse_categorical_accuracy: 0.6478
# Epoch 16/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.5455 - sparse_categorical_accuracy: 0.8143 - val_loss: 0.9566 - val_sparse_categorical_accuracy: 0.7045
# Epoch 17/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.5449 - sparse_categorical_accuracy: 0.8154 - val_loss: 1.2080 - val_sparse_categorical_accuracy: 0.5973
# Epoch 18/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.5105 - sparse_categorical_accuracy: 0.8260 - val_loss: 0.9417 - val_sparse_categorical_accuracy: 0.6736
# Epoch 19/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.5055 - sparse_categorical_accuracy: 0.8281 - val_loss: 0.9331 - val_sparse_categorical_accuracy: 0.7022
# Epoch 20/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.4832 - sparse_categorical_accuracy: 0.8362 - val_loss: 0.8757 - val_sparse_categorical_accuracy: 0.7092
# Epoch 21/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.4692 - sparse_categorical_accuracy: 0.8391 - val_loss: 0.9238 - val_sparse_categorical_accuracy: 0.6998
# Epoch 22/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.4710 - sparse_categorical_accuracy: 0.8387 - val_loss: 0.8627 - val_sparse_categorical_accuracy: 0.7136
# Epoch 23/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.4522 - sparse_categorical_accuracy: 0.8447 - val_loss: 0.8932 - val_sparse_categorical_accuracy: 0.7129
# Epoch 24/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.4298 - sparse_categorical_accuracy: 0.8526 - val_loss: 1.0019 - val_sparse_categorical_accuracy: 0.6970
# Epoch 25/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.4325 - sparse_categorical_accuracy: 0.8516 - val_loss: 0.8808 - val_sparse_categorical_accuracy: 0.7077
# Epoch 26/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.4399 - sparse_categorical_accuracy: 0.8498 - val_loss: 0.8951 - val_sparse_categorical_accuracy: 0.7103
# Epoch 27/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.4209 - sparse_categorical_accuracy: 0.8546 - val_loss: 0.9374 - val_sparse_categorical_accuracy: 0.7091
# Epoch 28/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.3882 - sparse_categorical_accuracy: 0.8655 - val_loss: 0.8358 - val_sparse_categorical_accuracy: 0.7234
# Epoch 29/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.3740 - sparse_categorical_accuracy: 0.8709 - val_loss: 0.8754 - val_sparse_categorical_accuracy: 0.7132
# Epoch 30/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.3720 - sparse_categorical_accuracy: 0.8713 - val_loss: 0.8425 - val_sparse_categorical_accuracy: 0.7328
# Epoch 31/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.3673 - sparse_categorical_accuracy: 0.8729 - val_loss: 0.9607 - val_sparse_categorical_accuracy: 0.6931
# Epoch 32/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.3624 - sparse_categorical_accuracy: 0.8751 - val_loss: 0.8426 - val_sparse_categorical_accuracy: 0.7304
# Epoch 33/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.3451 - sparse_categorical_accuracy: 0.8802 - val_loss: 0.8171 - val_sparse_categorical_accuracy: 0.7331
# Epoch 34/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.3427 - sparse_categorical_accuracy: 0.8812 - val_loss: 0.9655 - val_sparse_categorical_accuracy: 0.7132
# Epoch 35/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.3292 - sparse_categorical_accuracy: 0.8856 - val_loss: 0.9068 - val_sparse_categorical_accuracy: 0.7112
# Epoch 36/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.3261 - sparse_categorical_accuracy: 0.8867 - val_loss: 0.9443 - val_sparse_categorical_accuracy: 0.7135
# Epoch 37/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.3188 - sparse_categorical_accuracy: 0.8892 - val_loss: 0.8825 - val_sparse_categorical_accuracy: 0.7161
# Epoch 38/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.3000 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.8369 - val_sparse_categorical_accuracy: 0.7351
# Epoch 39/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2825 - sparse_categorical_accuracy: 0.9017 - val_loss: 0.8595 - val_sparse_categorical_accuracy: 0.7389
# Epoch 40/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2744 - sparse_categorical_accuracy: 0.9039 - val_loss: 0.9807 - val_sparse_categorical_accuracy: 0.7181
# Epoch 41/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.3141 - sparse_categorical_accuracy: 0.8904 - val_loss: 0.9976 - val_sparse_categorical_accuracy: 0.6825
# Epoch 42/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2741 - sparse_categorical_accuracy: 0.9040 - val_loss: 0.8626 - val_sparse_categorical_accuracy: 0.7285
# Epoch 43/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2503 - sparse_categorical_accuracy: 0.9124 - val_loss: 0.8405 - val_sparse_categorical_accuracy: 0.7459
# Epoch 44/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2472 - sparse_categorical_accuracy: 0.9137 - val_loss: 0.8606 - val_sparse_categorical_accuracy: 0.7264
# Epoch 45/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.2286 - sparse_categorical_accuracy: 0.9200 - val_loss: 0.8410 - val_sparse_categorical_accuracy: 0.7454
# Epoch 46/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2280 - sparse_categorical_accuracy: 0.9195 - val_loss: 0.9049 - val_sparse_categorical_accuracy: 0.7235
# Epoch 47/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.2343 - sparse_categorical_accuracy: 0.9179 - val_loss: 0.9845 - val_sparse_categorical_accuracy: 0.7279
# Epoch 48/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.2304 - sparse_categorical_accuracy: 0.9190 - val_loss: 0.8811 - val_sparse_categorical_accuracy: 0.7427
# Epoch 49/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2212 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.8910 - val_sparse_categorical_accuracy: 0.7413
# Epoch 50/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2265 - sparse_categorical_accuracy: 0.9206 - val_loss: 0.9311 - val_sparse_categorical_accuracy: 0.7324
# Epoch 51/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.2044 - sparse_categorical_accuracy: 0.9280 - val_loss: 0.8658 - val_sparse_categorical_accuracy: 0.7335
# Epoch 52/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1973 - sparse_categorical_accuracy: 0.9307 - val_loss: 0.9469 - val_sparse_categorical_accuracy: 0.7209
# Epoch 53/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.1996 - sparse_categorical_accuracy: 0.9301 - val_loss: 1.0013 - val_sparse_categorical_accuracy: 0.7311
# Epoch 54/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1975 - sparse_categorical_accuracy: 0.9307 - val_loss: 1.0369 - val_sparse_categorical_accuracy: 0.7148
# Epoch 55/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2109 - sparse_categorical_accuracy: 0.9260 - val_loss: 1.1568 - val_sparse_categorical_accuracy: 0.6846
# Epoch 56/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1934 - sparse_categorical_accuracy: 0.9319 - val_loss: 0.8658 - val_sparse_categorical_accuracy: 0.7539
# Epoch 57/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1762 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.8826 - val_sparse_categorical_accuracy: 0.7503
# Epoch 58/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1607 - sparse_categorical_accuracy: 0.9436 - val_loss: 0.9015 - val_sparse_categorical_accuracy: 0.7478
# Epoch 59/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1539 - sparse_categorical_accuracy: 0.9458 - val_loss: 0.9146 - val_sparse_categorical_accuracy: 0.7503
# Epoch 60/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1464 - sparse_categorical_accuracy: 0.9485 - val_loss: 0.9642 - val_sparse_categorical_accuracy: 0.7595
# Epoch 61/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1445 - sparse_categorical_accuracy: 0.9491 - val_loss: 1.0294 - val_sparse_categorical_accuracy: 0.7291
# Epoch 62/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1384 - sparse_categorical_accuracy: 0.9513 - val_loss: 0.9922 - val_sparse_categorical_accuracy: 0.7510
# Epoch 63/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1321 - sparse_categorical_accuracy: 0.9533 - val_loss: 1.0501 - val_sparse_categorical_accuracy: 0.7381
# Epoch 64/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.1569 - sparse_categorical_accuracy: 0.9445 - val_loss: 1.0518 - val_sparse_categorical_accuracy: 0.7424
# Epoch 65/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1485 - sparse_categorical_accuracy: 0.9476 - val_loss: 1.0872 - val_sparse_categorical_accuracy: 0.7344
# Epoch 66/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9475 - val_loss: 1.0740 - val_sparse_categorical_accuracy: 0.7191
# Epoch 67/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1505 - sparse_categorical_accuracy: 0.9469 - val_loss: 0.9602 - val_sparse_categorical_accuracy: 0.7489
# Epoch 68/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1278 - sparse_categorical_accuracy: 0.9550 - val_loss: 0.9420 - val_sparse_categorical_accuracy: 0.7552
# Epoch 69/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1619 - sparse_categorical_accuracy: 0.9433 - val_loss: 1.2024 - val_sparse_categorical_accuracy: 0.7098
# Epoch 70/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2108 - sparse_categorical_accuracy: 0.9261 - val_loss: 1.4190 - val_sparse_categorical_accuracy: 0.7033
# Epoch 71/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1517 - sparse_categorical_accuracy: 0.9464 - val_loss: 0.9683 - val_sparse_categorical_accuracy: 0.7466
# Epoch 72/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1231 - sparse_categorical_accuracy: 0.9565 - val_loss: 0.9687 - val_sparse_categorical_accuracy: 0.7566
# Epoch 73/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1138 - sparse_categorical_accuracy: 0.9598 - val_loss: 0.9803 - val_sparse_categorical_accuracy: 0.7502
# Epoch 74/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1141 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.9471 - val_sparse_categorical_accuracy: 0.7596
# Epoch 75/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1063 - sparse_categorical_accuracy: 0.9623 - val_loss: 0.9706 - val_sparse_categorical_accuracy: 0.7656
# Epoch 76/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1061 - sparse_categorical_accuracy: 0.9623 - val_loss: 1.0273 - val_sparse_categorical_accuracy: 0.7565
# Epoch 77/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1053 - sparse_categorical_accuracy: 0.9625 - val_loss: 1.0160 - val_sparse_categorical_accuracy: 0.7571
# Epoch 78/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1010 - sparse_categorical_accuracy: 0.9640 - val_loss: 1.0452 - val_sparse_categorical_accuracy: 0.7575
# Epoch 79/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1023 - sparse_categorical_accuracy: 0.9634 - val_loss: 1.0730 - val_sparse_categorical_accuracy: 0.7458
# Epoch 80/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0990 - sparse_categorical_accuracy: 0.9647 - val_loss: 1.0340 - val_sparse_categorical_accuracy: 0.7532
# Epoch 81/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0980 - sparse_categorical_accuracy: 0.9649 - val_loss: 1.0624 - val_sparse_categorical_accuracy: 0.7585
# Epoch 82/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0939 - sparse_categorical_accuracy: 0.9663 - val_loss: 1.0616 - val_sparse_categorical_accuracy: 0.7606
# Epoch 83/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0928 - sparse_categorical_accuracy: 0.9667 - val_loss: 1.0691 - val_sparse_categorical_accuracy: 0.7607
# Epoch 84/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0916 - sparse_categorical_accuracy: 0.9672 - val_loss: 1.0593 - val_sparse_categorical_accuracy: 0.7624
# Epoch 85/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0923 - sparse_categorical_accuracy: 0.9668 - val_loss: 1.1478 - val_sparse_categorical_accuracy: 0.7601
# Epoch 86/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.0881 - sparse_categorical_accuracy: 0.9684 - val_loss: 1.1276 - val_sparse_categorical_accuracy: 0.7571
# Epoch 87/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0887 - sparse_categorical_accuracy: 0.9681 - val_loss: 1.0850 - val_sparse_categorical_accuracy: 0.7536
# Epoch 88/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0859 - sparse_categorical_accuracy: 0.9691 - val_loss: 1.1343 - val_sparse_categorical_accuracy: 0.7515
# Epoch 89/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0836 - sparse_categorical_accuracy: 0.9699 - val_loss: 1.2002 - val_sparse_categorical_accuracy: 0.7481
# Epoch 90/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1093 - sparse_categorical_accuracy: 0.9607 - val_loss: 1.2720 - val_sparse_categorical_accuracy: 0.7322
# Epoch 91/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.1693 - sparse_categorical_accuracy: 0.9416 - val_loss: 2.3070 - val_sparse_categorical_accuracy: 0.6742
# Epoch 92/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.2195 - sparse_categorical_accuracy: 0.9233 - val_loss: 1.9554 - val_sparse_categorical_accuracy: 0.6169
# Epoch 93/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1548 - sparse_categorical_accuracy: 0.9455 - val_loss: 1.0503 - val_sparse_categorical_accuracy: 0.7426
# Epoch 94/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.1062 - sparse_categorical_accuracy: 0.9621 - val_loss: 1.0723 - val_sparse_categorical_accuracy: 0.7558
# Epoch 95/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0915 - sparse_categorical_accuracy: 0.9673 - val_loss: 1.0025 - val_sparse_categorical_accuracy: 0.7600
# Epoch 96/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0834 - sparse_categorical_accuracy: 0.9700 - val_loss: 1.0640 - val_sparse_categorical_accuracy: 0.7571
# Epoch 97/100
# 60/60 [==============================] - 37s 611ms/step - loss: 0.0800 - sparse_categorical_accuracy: 0.9711 - val_loss: 1.0547 - val_sparse_categorical_accuracy: 0.7617
# Epoch 98/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0769 - sparse_categorical_accuracy: 0.9722 - val_loss: 1.0796 - val_sparse_categorical_accuracy: 0.7627
# Epoch 99/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0764 - sparse_categorical_accuracy: 0.9723 - val_loss: 1.0875 - val_sparse_categorical_accuracy: 0.7618
# Epoch 100/100
# 60/60 [==============================] - 37s 612ms/step - loss: 0.0759 - sparse_categorical_accuracy: 0.9725 - val_loss: 1.1278 - val_sparse_categorical_accuracy: 0.7610

# %%
# Генерация случайного списка индексов в количестве count между (0, len(x_val)
indexes = np.random.randint(0, len(x_val), 5)
    
# Вычисление предсказания сети для картинок с отобранными индексами
predict = np.argmax(model.predict(x_val[indexes]), axis=-1)

# Подготовка цветов классов для отрисовки предсказания
orig = labels_to_rgb(predict[..., None])
fig, axs = plt.subplots(3, 5, figsize=(25, 15)) 
    
# Отрисовка результата работы модели
for i in range(5):
    # Отображение на графике в первой линии предсказания модели
    axs[0, 0].set_title('Результат работы модели:')
    axs[0, i].imshow(orig[i])
    axs[0, i].axis('off')

    # Отображение на графике во второй линии сегментированного изображения из y_val
    axs[1, 0].set_title('Оригинальное сегментированное')
    axs[1, i].imshow(val_segments[indexes[i]])
    axs[1 ,i].axis('off')

    # Отображение на графике в третьей линии оригинального изображения
    axs[2, 0].set_title('Оригинальное изображение')
    axs[2, i].imshow(val_images[indexes[i]])
    axs[2 ,i].axis('off')

plt.show()
